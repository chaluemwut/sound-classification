# %%
import sklearn
import librosa
import librosa.display
print("Hello world")

samples, sample_rate = librosa.load('data.wav')
mfcc = librosa.feature.mfcc(y=samples, sr=sample_rate)
mel_scale = librosa.feature.melspectrogram(y=samples, sr=sample_rate)
# librosa.display.specshow(mfcc)
librosa.display.specshow(mel_scale)
# print(mel_scale)
# print(mfcc)
# Out:
# Hello world
